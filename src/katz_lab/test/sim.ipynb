# %%
from qm_saas import QmSaas
from qm import QuantumMachinesManager
from qm_saas import QOPVersion
from katz_lab.experiments.calibrations.iq_blobs import *
import numpy as np

# %%
client = QmSaas(
    email="asaf.solonnikov@mail.huji.ac.il", password="CYbv+v3xVyVvyUhi6o+iEQ=="
)

instance = client.simulator()

# %%
print("Supported versions:")
for version in client.versions():
    print(f"\t- {version}")

# %%
with client.simulator() as instance:
    # Use the instance object to simulate QUA programs
    qmm = QuantumMachinesManager(
        host=instance.host,
        port=instance.port,
        connection_headers=instance.default_connection_headers,
    )
    # Continue as usual with opening a quantum machine and simulation of a qua program
# Out:
# 2025-12-05 18:34:21,188 - qm - INFO     - Performing health check
# 2025-12-05 18:34:21,382 - qm - INFO     - Cluster healthcheck completed successfully.

# %%
options = OptionsIQBlobs()
options.simulate = True

experiment = IQBlobsExperiment(
    qubit="q10",
    options=options,
    qmm=qmm,
)

experiment.run()
# Out:
# 2025-12-05 18:34:38,302 - qm - INFO     - Simulating program.
# /Users/asafsolonnikov/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning: 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
#   warnings.warn(
# ---------------------------------------------------------------------------
# GRPCError                                 Traceback (most recent call last)
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/api/base_api.py:47, in _handle_connection_error(timeout)
#      46 try:
# ---> 47     yield
#      48 except grpclib.exceptions.GRPCError as e:
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/api/base_api.py:105, in BaseApi._run(self, coroutine, timeout)
#     104 with _handle_connection_error(timeout):
# --> 105     return run_async(coroutine)
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/utils/async_utils.py:35, in run_async(coroutine)
#      34 def run_async(coroutine: Coroutine[Any, Any, T]) -> T:
# ---> 35     return create_future(coroutine).result()
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/grpc/v2/__init__.py:1946, in QmmServiceStub.simulate(self, qmm_service_simulate_request, timeout, deadline, metadata)
#    1938 async def simulate(
#    1939     self,
#    1940     qmm_service_simulate_request: "QmmServiceSimulateRequest",
#    (...)
#    1944     metadata: Optional["MetadataLike"] = None
#    1945 ) -> "QmmServiceSimulateResponse":
# -> 1946     return await self._unary_unary(
#    1947         "/qm.grpc.v2.QmmService/Simulate",
#    1948         qmm_service_simulate_request,
#    1949         QmmServiceSimulateResponse,
#    1950         timeout=timeout,
#    1951         deadline=deadline,
#    1952         metadata=metadata,
#    1953     )
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/betterproto/grpc/grpclib_client.py:85, in ServiceStub._unary_unary(self, route, request, response_type, timeout, deadline, metadata)
#      84     await stream.send_message(request, end=True)
# ---> 85     response = await stream.recv_message()
#      86 assert response is not None
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/grpclib/client.py:425, in Stream.recv_message(self)
#     424 if not self._recv_initial_metadata_done:
# --> 425     await self.recv_initial_metadata()
#     427 with self._wrapper:
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/grpclib/client.py:393, in Stream.recv_initial_metadata(self)
#     391     self.trailing_metadata = tm
# --> 393     self._raise_for_grpc_status(status, message, details)
#     394 else:
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/grpclib/client.py:345, in Stream._raise_for_grpc_status(self, status, message, details)
#     344 if status is not Status.OK:
# --> 345     raise GRPCError(status, message, details)
#
# GRPCError: (<Status.UNKNOWN: 2>, 'Internal Server Error', None)
#
# The above exception was the direct cause of the following exception:
#
# QMConnectionError                         Traceback (most recent call last)
# Cell In[5], line 10
#       2 options.simulate = True
#       4 experiment = IQBlobsExperiment(
#       5     qubit="q10",
#       6     options=options,
#       7     qmm=qmm,
#       8 )
# ---> 10 experiment.run()
#
# File ~/Developer/SERVER/katz-lab/src/katz_lab/experiments/core/base_experiment.py:74, in BaseExperiment.run(self)
#      69 import matplotlib.pyplot as plt
#      71 simulation_config = SimulationConfig(
#      72     duration=10_000
#      73 )  # In clock cycles = 4ns
# ---> 74 job = self.qmm.simulate(self.config, self.program, simulation_config)
#      75 job.get_simulated_samples().con1.plot()
#      77 plt.show()
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/quantum_machines_manager.py:549, in QuantumMachinesManager.simulate(self, config, program, simulate, compiler_options, strict, flags)
#     547 if self._api:
#     548     request = create_simulation_request(pb_config, program, simulate, standardized_options)
# --> 549     simulated_job = self._api.simulate(
#     550         request.config, request.high_level_program, request.simulate, request.controller_connections
#     551     )
#     552     return simulated_job
#     553 else:
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/api/v2/qmm_api.py:255, in QmmApi.simulate(self, config, program, simulate, controller_connections)
#     252 logger.info("Simulating program.")
#     254 with handle_simulation_error():
# --> 255     response = self._run(self._stub.simulate(request, timeout=self._timeout))
#     257 _log_messages(response.messages)
#     259 return self._get_simulated_job(response.job_id, response.simulated)
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/api/v2/base_api_v2.py:19, in BaseApiV2._run(self, coroutine, timeout)
#      18 def _run(self, coroutine: Coroutine[Any, Any, ResponseProtocol[SuccessType, ErrorType]], timeout: Optional[float] = None) -> SuccessType:  # type: ignore[override]
# ---> 19     response = super()._run(coroutine, timeout)  # type: ignore[type-var]
#      20     if response.is_set("success"):  # type: ignore[attr-defined]
#      21         return response.success
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/api/base_api.py:104, in BaseApi._run(self, coroutine, timeout)
#     101 if timeout is None:
#     102     timeout = self._timeout
# --> 104 with _handle_connection_error(timeout):
#     105     return run_async(coroutine)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File ~/Developer/SERVER/katz-lab/venv/lib/python3.10/site-packages/qm/api/base_api.py:55, in _handle_connection_error(timeout)
#      51     if e.status == Status.UNIMPLEMENTED:
#      52         raise GatewayNotImplementedError(
#      53             f"Encountered connection error from QOP: details: {e.message}, status: {e.status}"
#      54         ) from e
# ---> 55     raise QMConnectionError(
#      56         f"Encountered connection error from QOP: details: {e.message}, status: {e.status}"
#      57     ) from e
#      58 except asyncio.TimeoutError as e:
#      59     if is_debug():
#
# QMConnectionError: Encountered connection error from QOP: details: Internal Server Error, status: Status.UNKNOWN

# %%
# Out:
# Supported versions:
# 	- v3_5_1
# 	- v3_5_0
# 	- v3_4_1
# 	- v3_3_0
# 	- v3_2_4
# 	- v3_2_0
# 	- v3_1_0
# 	- v2_5_0
# 	- v2_4_4
# 	- v2_4_0
# 	- v2_2_2
# 	- v2_2_0
# 	- v2_1_3
# 	- v1_30_2133
